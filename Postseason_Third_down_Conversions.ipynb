# %% [markdown]
# <a href="https://colab.research.google.com/github/SavantLogics/SavantLogics/blob/main/Postseason_Third_down_Conversions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd 
import math
import matplotlib.pyplot as plt 
import io

# %%
from google.colab import files

nfl = files.upload()
# Out:
#      <input type="file" id="files-80ca7f71-5ed1-400b-922a-e68803993496" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-80ca7f71-5ed1-400b-922a-e68803993496">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving NFL_Teams_Postseason_Stats_2021.csv to NFL_Teams_Postseason_Stats_2021.csv

# %% [markdown]
# This is pulled from
# https://www.espn.com/nfl/stats/team/_/view/offense/stat/downs/table/miscellaneous/sort/fourthDownAttempts/dir/desc

# %%
# Show spreadsheet of stats for postseason teams

df_nfl = pd.read_csv(io.BytesIO(nfl['NFL_Teams_Postseason_Stats_2021.csv']))
df_nfl
# Out:
#                     TEAM   GP  ... Penalties TOTAL  Penalties YDS
# 0     Kansas City Chiefs  2.0  ...               4           35.0
# 1          Buffalo Bills  2.0  ...               6           62.0
# 2   Tampa Bay Buccaneers  2.0  ...               8           96.0
# 3       Los Angeles Rams  2.0  ...              10           93.0
# 4     Cincinnati Bengals  2.0  ...              13          102.0
# 5    San Francisco 49ers  2.0  ...              14           98.0
# 6      Las Vegas Raiders  1.0  ...               7           46.0
# 7         Dallas Cowboys  1.0  ...              14           89.0
# 8   New England Patriots  1.0  ...               5           34.0
# 9    Pittsburgh Steelers  1.0  ...               4           45.0
# 10      Tennessee Titans  1.0  ...               2           15.0
# 11     Green Bay Packers  1.0  ...               5           25.0
# 12   Philadelphia Eagles  1.0  ...               4           45.0
# ...

# %%
# Display Histogram of all columns

df_nfl.hist(bins=5, figsize=(15, 10), grid=False)
plt.show()

# %%
# Show and compare 3rd down and 4th down attempts 

df_nfl.boxplot(grid=False, column=["3rd Downs ATT", "4th Downs ATT"])
plt.show()
